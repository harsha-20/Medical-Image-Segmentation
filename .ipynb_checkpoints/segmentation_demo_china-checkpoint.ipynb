# %% [markdown]
# # Load Libraries

# %%
import os
os.makedirs("input/ChinaSet_AllFiles/segmentation", exist_ok=True)
os.makedirs("input/ChinaSet_AllFiles/segmentation/test", exist_ok=True)
os.makedirs("input/ChinaSet_AllFiles/segmentation/train", exist_ok=True)
os.makedirs("input/ChinaSet_AllFiles/segmentation/train/augumentation", exist_ok=True)
os.makedirs("input/ChinaSet_AllFiles/segmentation/train/image", exist_ok=True)
os.makedirs("input/ChinaSet_AllFiles/segmentation/train/mask", exist_ok=True)
os.makedirs("input/ChinaSet_AllFiles/segmentation/train/dilate", exist_ok=True)
os.makedirs("input/ChinaSet_AllFiles/segmentation/test/image", exist_ok=True)
os.makedirs("input/ChinaSet_AllFiles/segmentation/test/mask", exist_ok=True)
os.makedirs("input/ChinaSet_AllFiles/segmentation/test/dilate", exist_ok=True)

# %%
from __future__ import print_function
# %matplotlib inline  
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import cv2
import numpy as np
#Import our classes
#from nets.unet import generate_batch_norm_unet

#from nets.unet import unet_model
from utils.image import ImageDataGenerator
from utils.dice import dice_coef

#Import specific keras classes
from keras.models import *
from keras.layers import *
from keras.optimizers import *
from keras.callbacks import  ModelCheckpoint, CSVLogger, ReduceLROnPlateau,LearningRateScheduler
from keras.utils import to_categorical

from glob import glob
from tqdm import tqdm



#Make sure we remove any randomness
from numpy.random import seed
seed(1)

try:
    from itertools import izip as zip
except ImportError: # will be 3.x series
    pass

#UNCOMMENT BELOW TO DETERMINE GPU
from keras import backend as K
import tensorflow as tf
import os
 #Use one GPU
if K.backend() == 'Tensorflow':
    # Use only gpu #X (with tf.device(/gpu:X) does not work)
    os.environ['CUDA_VISIBLE_DEVICES'] = '0'
    # Automatically choose an existing and supported device if the specified one does not exist
    config = tf.ConfigProto(allow_soft_placement=True, log_device_placement=False)
    # To constrain the use of gpu memory, otherwise all memory is used
    config.gpu_options.allow_growth = True
    sess = tf.Session(config=config)
    K.set_session(sess)

# %% [markdown]
# # Define Directory Paths

# %%
INPUT_DIR = os.path.join(os.getcwd(), "input\ChinaSet_AllFiles")
SEGMENTATION_DIR = os.path.join(INPUT_DIR, "segmentation")
SEGMENTATION_TEST_DIR = os.path.join(SEGMENTATION_DIR, "test")
SEGMENTATION_TRAIN_DIR = os.path.join(SEGMENTATION_DIR, "train")
SEGMENTATION_AUG_DIR = os.path.join(SEGMENTATION_TRAIN_DIR, "augmentation")
SEGMENTATION_IMAGE_DIR = os.path.join(SEGMENTATION_TRAIN_DIR, "image")
SEGMENTATION_MASK_DIR = os.path.join(SEGMENTATION_TRAIN_DIR, "mask")
SEGMENTATION_DILATE_DIR = os.path.join(SEGMENTATION_TRAIN_DIR, "dilate")
SEGMENTATION_TEST_IMAGE_DIR = os.path.join(SEGMENTATION_TEST_DIR, "image")
SEGMENTATION_TEST_MASK_DIR = os.path.join(SEGMENTATION_TEST_DIR, "mask")
SEGMENTATION_TEST_DILATE_DIR = os.path.join(SEGMENTATION_TEST_DIR, "dilate")
SHENZHEN_IMAGE_DIR = os.path.join(INPUT_DIR, "CXR_png")
SHENZHEN_MASK_DIR = os.path.join(INPUT_DIR, "CXR_mask")
DILATE_KERNEL = np.ones((15, 15), np.uint8)

#BATCH_SIZE=2

#Prod
#EPOCHS=56

# %% [markdown]
# # Helper functions to display segmented images

# %%
def add_colored_dilate(image, mask_image, dilate_image):
    mask_image_gray = cv2.cvtColor(mask_image, cv2.COLOR_BGR2GRAY)
    dilate_image_gray = cv2.cvtColor(dilate_image, cv2.COLOR_BGR2GRAY)
    
    mask = cv2.bitwise_and(mask_image, mask_image, mask=mask_image_gray)
    dilate = cv2.bitwise_and(dilate_image, dilate_image, mask=dilate_image_gray)
    
    mask_coord = np.where(mask!=[0,0,0])
    dilate_coord = np.where(dilate!=[0,0,0])

    mask[mask_coord[0],mask_coord[1],:]=[255,0,0]
    dilate[dilate_coord[0],dilate_coord[1],:] = [0,0,255]

    ret = cv2.addWeighted(image, 0.7, dilate, 0.3, 0)
    ret = cv2.addWeighted(ret, 0.7, mask, 0.3, 0)

    return ret

def add_colored_mask(image, mask_image):
    mask_image_gray = cv2.cvtColor(mask_image, cv2.COLOR_BGR2GRAY)
    
    mask = cv2.bitwise_and(mask_image, mask_image, mask=mask_image_gray)
    
    mask_coord = np.where(mask!=[0,0,0])

    mask[mask_coord[0],mask_coord[1],:]=[255,0,0]

    ret = cv2.addWeighted(image, 0.7, mask, 0.3, 0)

    return ret

def diff_mask(ref_image, mask_image):
    mask_image_gray = cv2.cvtColor(mask_image, cv2.COLOR_BGR2GRAY)
    
    mask = cv2.bitwise_and(mask_image, mask_image, mask=mask_image_gray)
    
    mask_coord = np.where(mask!=[0,0,0])

    mask[mask_coord[0],mask_coord[1],:]=[255,0,0]

    ret = cv2.addWeighted(ref_image, 0.7, mask, 0.3, 0)
    return ret

# %% [markdown]
# 1.Resize Shenzhen Hospital chest x-ray images to 512 X 512 pixels
#
# 2.Dilate masks to gain more information on the edge of lungs
#
# 3.Split images into training and test datasets
#
# 4.Write images to /segmentation directory

# %%
shenzhen_mask_dir = glob(os.path.join(SHENZHEN_MASK_DIR, '*.png'))
shenzhen_test = shenzhen_mask_dir[0:50]
shenzhen_train= shenzhen_mask_dir[50:]

for mask_file in tqdm(shenzhen_mask_dir):
    base_file = os.path.basename(mask_file).replace("_mask", "")
    image_file = os.path.join(SHENZHEN_IMAGE_DIR, base_file)

    image = cv2.imread(image_file)
    mask = cv2.imread(mask_file, cv2.IMREAD_GRAYSCALE)
        
    image = cv2.resize(image, (512, 512))
    mask = cv2.resize(mask, (512, 512))
    mask_dilate = cv2.dilate(mask, DILATE_KERNEL, iterations=1)
    
    if (mask_file in shenzhen_train):
        cv2.imwrite(os.path.join(SEGMENTATION_IMAGE_DIR, base_file), \
                    image)
        cv2.imwrite(os.path.join(SEGMENTATION_MASK_DIR, base_file), \
                    mask)
        cv2.imwrite(os.path.join(SEGMENTATION_DILATE_DIR, base_file), \
                    mask_dilate)
    elif (mask_file in shenzhen_test):
        cv2.imwrite(os.path.join(SEGMENTATION_TEST_IMAGE_DIR, base_file), \
                    image)
        cv2.imwrite(os.path.join(SEGMENTATION_TEST_MASK_DIR, base_file), \
                    mask)
        cv2.imwrite(os.path.join(SEGMENTATION_TEST_DILATE_DIR, base_file), \
                    mask_dilate)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 566/566 [03:05<00:00,  2.47it/s]

# %% [markdown]
# # Display images and shapes for sanity check

# %%
base_file = os.path.basename(shenzhen_train[0].replace("_mask", ""))

image_file = os.path.join(SEGMENTATION_IMAGE_DIR, base_file)
mask_image_file = os.path.join(SEGMENTATION_MASK_DIR, base_file)
dilate_image_file = os.path.join(SEGMENTATION_DILATE_DIR, base_file)

image = cv2.imread(image_file)
mask_image = cv2.imread(mask_image_file)
dilate_image = cv2.imread(dilate_image_file)
merged_image = add_colored_dilate(image, mask_image, dilate_image)
                          
fig, axs = plt.subplots(2, 4, figsize=(15, 8))

axs[0, 0].set_title("X-Ray")
axs[0, 0].imshow(image)

axs[0, 1].set_title("Mask")
axs[0, 1].imshow(mask_image)

axs[0, 2].set_title("Dilate")
axs[0, 2].imshow(dilate_image)

axs[0, 3].set_title("Merged")
axs[0, 3].imshow(merged_image)

base_file = os.path.basename(shenzhen_test[0].replace("_mask", ""))

image_file = os.path.join(SEGMENTATION_TEST_IMAGE_DIR, base_file)
mask_image_file = os.path.join(SEGMENTATION_TEST_MASK_DIR, base_file)
dilate_image_file = os.path.join(SEGMENTATION_TEST_DILATE_DIR, base_file)

image = cv2.imread(image_file)
mask_image = cv2.imread(mask_image_file)
dilate_image = cv2.imread(dilate_image_file)
merged_image = add_colored_dilate(image, mask_image, dilate_image)

axs[1, 0].set_title("X-Ray")
axs[1, 0].imshow(image)

axs[1, 1].set_title("Mask")
axs[1, 1].imshow(mask_image)

axs[1, 2].set_title("Dilate")
axs[1, 2].imshow(dilate_image)

axs[1, 3].set_title("Merged")
axs[1, 3].imshow(merged_image)

# %%
print ('Image shape: ',image.shape)
print ('Mask shape: ',mask_image.shape)
train_files = glob(os.path.join(SEGMENTATION_IMAGE_DIR, "*.png"))
test_files = glob(os.path.join(SEGMENTATION_TEST_IMAGE_DIR, "*.png"))
mask_files = glob(os.path.join(SEGMENTATION_MASK_DIR, "*.png"))
dilate_files = glob(os.path.join(SEGMENTATION_DILATE_DIR, "*.png"))

(len(train_files), \
 len(test_files), \
 len(mask_files), \
 len(dilate_files))
# Out:
# Image shape:  (512, 512, 3)
# Mask shape:  (512, 512, 3)
# (516, 50, 516, 516)

# %% [markdown]
# # Targets in neural network are binary representation. So our masks.

# %% [markdown]
# # Data Generators
#
# ## Data generators in Keras are iterators that perform slow loading of data. Imagine if you had to train a model on 1M images. You cannot preload them in one big numpy array. You need to load them in batches and then process them through your model

# %%
# From: https://github.com/zhixuhao/unet/blob/master/data.py
def train_generator(batch_size, train_path, image_folder, mask_folder, aug_dict,
        image_color_mode="grayscale",
        mask_color_mode="grayscale",
        image_save_prefix="image",
        mask_save_prefix="mask",
        save_to_dir=None,
        target_size=(256,256),
        seed=1):
    '''
    can generate image and mask at the same time use the same seed for
    image_datagen and mask_datagen to ensure the transformation for image
    and mask is the same if you want to visualize the results of generator,
    set save_to_dir = "your path"
    '''
    image_datagen = ImageDataGenerator(**aug_dict)
    mask_datagen = ImageDataGenerator(**aug_dict)
    
    image_generator = image_datagen.flow_from_directory(
        train_path,
        classes = [image_folder],
        class_mode = None,
        color_mode = image_color_mode,
        target_size = target_size,
        batch_size = batch_size,
        save_to_dir = save_to_dir,
        save_prefix  = image_save_prefix,
        seed = seed)

    mask_generator = mask_datagen.flow_from_directory(
        train_path,
        classes = [mask_folder],
        class_mode = None,
        color_mode = mask_color_mode,
        target_size = target_size,
        batch_size = batch_size,
        save_to_dir = save_to_dir,
        save_prefix  = mask_save_prefix,
        seed = seed)

    train_gen = zip(image_generator, mask_generator)
    
    for (img, mask) in train_gen:
        img, mask = adjust_data(img, mask)
        yield (img,mask)

def adjust_data(img,mask):
    img = img / 255
    mask = mask / 255
    mask[mask > 0.5] = 1
    mask[mask <= 0.5] = 0
    
    return (img, mask)

# %% [markdown]
# # UNET MODEL

# %%
# From: https://github.com/jocicmarko/ultrasound-nerve-segmentation/blob/master/train.py
def dice_coef(y_true, y_pred):
    y_true_f = keras.flatten(y_true)
    y_pred_f = keras.flatten(y_pred)
    intersection = keras.sum(y_true_f * y_pred_f)
    return (2. * intersection + 1) / (keras.sum(y_true_f) + keras.sum(y_pred_f) + 1)

def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

def unet(input_size=(256,256,1)):
    inputs = Input(input_size)
    
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(inputs)
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(pool1)
    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(pool2)
    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(pool3)
    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(pool4)
    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(conv5)

    up6 = concatenate([Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(conv5), conv4], axis=3)
    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(up6)
    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv6)

    up7 = concatenate([Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(conv6), conv3], axis=3)
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(up7)
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv7)

    up8 = concatenate([Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(conv7), conv2], axis=3)
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(up8)
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv8)

    up9 = concatenate([Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(conv8), conv1], axis=3)
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(up9)
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv9)

    conv10 = Conv2D(1, (1, 1), activation='sigmoid')(conv9)

    return Model(inputs=[inputs], outputs=[conv10])

# %% [markdown]
# # Helper Functions to load x-ray images

# %%
# From: https://github.com/zhixuhao/unet/blob/master/data.py
def test_load_image(test_file, target_size=(256,256)):
    img = cv2.imread(test_file, cv2.IMREAD_GRAYSCALE)
    img = img / 255
    img = cv2.resize(img, target_size)
    img = np.reshape(img, img.shape + (1,))
    img = np.reshape(img,(1,) + img.shape)
    return img

def test_generator(test_files, target_size=(256,256)):
    for test_file in test_files:
        yield test_load_image(test_file, target_size)
        
def save_result(save_path, npyfile, test_files):
    for i, item in enumerate(npyfile):
        result_file = test_files[i]
        img = (item[:, :, 0] * 255.).astype(np.uint8)

        filename, fileext = os.path.splitext(os.path.basename(result_file))

        result_file = os.path.join(save_path, "%s_predict%s" % (filename, fileext))

        cv2.imwrite(result_file, img)

# %%
def add_suffix(base_file, suffix):
    filename, fileext = os.path.splitext(base_file)
    return "%s_%s%s" % (filename, suffix, fileext)

test_files = [test_file for test_file in glob(os.path.join(SEGMENTATION_TEST_IMAGE_DIR, "*.png")) ]
dilate_files = [dilate_file for dilate_file in glob(os.path.join(SEGMENTATION_TEST_DILATE_DIR,"*.png"))]

validation_data = (test_load_image(test_files[0], target_size=(512, 512)),
                    test_load_image(dilate_files[0], target_size=(512, 512)))

len(test_files), len(validation_data)
# Out:
# (50, 2)

# %% [markdown]
# # Prepare the UNET Model and train

# %%
EPOCHS = 4
BATCH_SIZE = 4
from keras.layers import Input
train_generator_args = dict()
"""
train_generator_args = dict(rotation_range=0.2,
                            width_shift_range=0.05,
                            height_shift_range=0.05,
                            shear_range=0.05,
                            zoom_range=0.05,
                            horizontal_flip=True,
                            fill_mode='nearest')
"""
train_gen = train_generator(BATCH_SIZE,
                            SEGMENTATION_TRAIN_DIR,
                            'image',
                            'dilate', 
                            train_generator_args,
                            target_size=(512,512),
                            save_to_dir=None)
                            #save_to_dir=os.path.abspath(SEGMENTATION_AUG_DIR))


model = unet(input_size=(512,512,1))
model.compile(optimizer=Adam(lr=1e-5), loss=dice_coef_loss, \
                  metrics=[dice_coef, 'binary_accuracy'])
model.summary()

model_checkpoint = ModelCheckpoint('unet_lung_seg.hdf5', 
                                   monitor='loss', 
                                   verbose=1, 
                                   save_best_only=True)

history = model.fit_generator(train_gen,
                              steps_per_epoch=len(train_files) / BATCH_SIZE, 
                              epochs=EPOCHS, 
                              callbacks=[model_checkpoint],
                              validation_data = validation_data)
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            (None, 512, 512, 1)  0
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 512, 512, 32) 320         input_4[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 512, 512, 32) 9248        conv2d_58[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_13 (MaxPooling2D) (None, 256, 256, 32) 0           conv2d_59[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 256, 256, 64) 18496       max_pooling2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 256, 256, 64) 36928       conv2d_60[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_14 (MaxPooling2D) (None, 128, 128, 64) 0           conv2d_61[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 128, 128, 128 73856       max_pooling2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 128, 128, 128 147584      conv2d_62[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_15 (MaxPooling2D) (None, 64, 64, 128)  0           conv2d_63[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 64, 64, 256)  295168      max_pooling2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 64, 64, 256)  590080      conv2d_64[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_16 (MaxPooling2D) (None, 32, 32, 256)  0           conv2d_65[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 32, 32, 512)  1180160     max_pooling2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 32, 32, 512)  2359808     conv2d_66[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_13 (Conv2DTran (None, 64, 64, 256)  524544      conv2d_67[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 64, 64, 512)  0           conv2d_transpose_13[0][0]
#                                                                  conv2d_65[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 64, 64, 256)  1179904     concatenate_13[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 64, 64, 256)  590080      conv2d_68[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_14 (Conv2DTran (None, 128, 128, 128 131200      conv2d_69[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 128, 128, 256 0           conv2d_transpose_14[0][0]
#                                                                  conv2d_63[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 128, 128, 128 295040      concatenate_14[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 128, 128, 128 147584      conv2d_70[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_15 (Conv2DTran (None, 256, 256, 64) 32832       conv2d_71[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 256, 256, 128 0           conv2d_transpose_15[0][0]
#                                                                  conv2d_61[0][0]
# __________________________________________________________________________________________________
# conv2d_72 (Conv2D)              (None, 256, 256, 64) 73792       concatenate_15[0][0]
# __________________________________________________________________________________________________
# conv2d_73 (Conv2D)              (None, 256, 256, 64) 36928       conv2d_72[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_16 (Conv2DTran (None, 512, 512, 32) 8224        conv2d_73[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, 512, 512, 64) 0           conv2d_transpose_16[0][0]
#                                                                  conv2d_59[0][0]
# __________________________________________________________________________________________________
# conv2d_74 (Conv2D)              (None, 512, 512, 32) 18464       concatenate_16[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 512, 512, 32) 9248        conv2d_74[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 512, 512, 1)  33          conv2d_75[0][0]
# ==================================================================================================
# Total params: 7,759,521
# Trainable params: 7,759,521
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/4
# Found 516 images belonging to 1 classes.
# Found 516 images belonging to 1 classes.
# 114/129 [=========================>....] - ETA: 7:07 - loss: -0.3384 - dice_coef: 0.3384 - binary_accuracy: 0.73 - ETA: 4:16 - loss: -0.3611 - dice_coef: 0.3611 - binary_accuracy: 0.70 - ETA: 3:19 - loss: -0.3704 - dice_coef: 0.3704 - binary_accuracy: 0.69 - ETA: 2:50 - loss: -0.3662 - dice_coef: 0.3662 - binary_accuracy: 0.70 - ETA: 2:32 - loss: -0.3752 - dice_coef: 0.3752 - binary_accuracy: 0.69 - ETA: 2:20 - loss: -0.3811 - dice_coef: 0.3811 - binary_accuracy: 0.68 - ETA: 2:12 - loss: -0.3798 - dice_coef: 0.3798 - binary_accuracy: 0.68 - ETA: 2:05 - loss: -0.3799 - dice_coef: 0.3799 - binary_accuracy: 0.68 - ETA: 1:59 - loss: -0.3821 - dice_coef: 0.3821 - binary_accuracy: 0.67 - ETA: 1:55 - loss: -0.3815 - dice_coef: 0.3815 - binary_accuracy: 0.67 - ETA: 1:51 - loss: -0.3820 - dice_coef: 0.3820 - binary_accuracy: 0.67 - ETA: 1:48 - loss: -0.3817 - dice_coef: 0.3817 - binary_accuracy: 0.67 - ETA: 1:45 - loss: -0.3815 - dice_coef: 0.3815 - binary_accuracy: 0.67 - ETA: 1:43 - loss: -0.3820 - dice_coef: 0.3820 - binary_accuracy: 0.67 - ETA: 1:40 - loss: -0.3814 - dice_coef: 0.3814 - binary_accuracy: 0.67 - ETA: 1:38 - loss: -0.3804 - dice_coef: 0.3804 - binary_accuracy: 0.67 - ETA: 1:36 - loss: -0.3783 - dice_coef: 0.3783 - binary_accuracy: 0.67 - ETA: 1:34 - loss: -0.3773 - dice_coef: 0.3773 - binary_accuracy: 0.67 - ETA: 1:33 - loss: -0.3758 - dice_coef: 0.3758 - binary_accuracy: 0.67 - ETA: 1:31 - loss: -0.3754 - dice_coef: 0.3754 - binary_accuracy: 0.67 - ETA: 1:30 - loss: -0.3753 - dice_coef: 0.3753 - binary_accuracy: 0.66 - ETA: 1:28 - loss: -0.3747 - dice_coef: 0.3747 - binary_accuracy: 0.66 - ETA: 1:27 - loss: -0.3757 - dice_coef: 0.3757 - binary_accuracy: 0.66 - ETA: 1:25 - loss: -0.3767 - dice_coef: 0.3767 - binary_accuracy: 0.66 - ETA: 1:24 - loss: -0.3773 - dice_coef: 0.3773 - binary_accuracy: 0.65 - ETA: 1:23 - loss: -0.3781 - dice_coef: 0.3781 - binary_accuracy: 0.65 - ETA: 1:22 - loss: -0.3785 - dice_coef: 0.3785 - binary_accuracy: 0.65 - ETA: 1:21 - loss: -0.3783 - dice_coef: 0.3783 - binary_accuracy: 0.65 - ETA: 1:20 - loss: -0.3780 - dice_coef: 0.3780 - binary_accuracy: 0.65 - ETA: 1:18 - loss: -0.3779 - dice_coef: 0.3779 - binary_accuracy: 0.65 - ETA: 1:17 - loss: -0.3782 - dice_coef: 0.3782 - binary_accuracy: 0.64 - ETA: 1:16 - loss: -0.3783 - dice_coef: 0.3783 - binary_accuracy: 0.64 - ETA: 1:15 - loss: -0.3777 - dice_coef: 0.3777 - binary_accuracy: 0.64 - ETA: 1:14 - loss: -0.3776 - dice_coef: 0.3776 - binary_accuracy: 0.64 - ETA: 1:13 - loss: -0.3767 - dice_coef: 0.3767 - binary_accuracy: 0.64 - ETA: 1:12 - loss: -0.3769 - dice_coef: 0.3769 - binary_accuracy: 0.64 - ETA: 1:11 - loss: -0.3766 - dice_coef: 0.3766 - binary_accuracy: 0.64 - ETA: 1:10 - loss: -0.3777 - dice_coef: 0.3777 - binary_accuracy: 0.64 - ETA: 1:10 - loss: -0.3774 - dice_coef: 0.3774 - binary_accuracy: 0.64 - ETA: 1:09 - loss: -0.3781 - dice_coef: 0.3781 - binary_accuracy: 0.63 - ETA: 1:08 - loss: -0.3795 - dice_coef: 0.3795 - binary_accuracy: 0.63 - ETA: 1:07 - loss: -0.3798 - dice_coef: 0.3798 - binary_accuracy: 0.62 - ETA: 1:06 - loss: -0.3808 - dice_coef: 0.3808 - binary_accuracy: 0.62 - ETA: 1:05 - loss: -0.3807 - dice_coef: 0.3807 - binary_accuracy: 0.61 - ETA: 1:04 - loss: -0.3807 - dice_coef: 0.3807 - binary_accuracy: 0.60 - ETA: 1:03 - loss: -0.3801 - dice_coef: 0.3801 - binary_accuracy: 0.60 - ETA: 1:02 - loss: -0.3789 - dice_coef: 0.3789 - binary_accuracy: 0.59 - ETA: 1:02 - loss: -0.3788 - dice_coef: 0.3788 - binary_accuracy: 0.58 - ETA: 1:01 - loss: -0.3791 - dice_coef: 0.3791 - binary_accuracy: 0.58 - ETA: 1:00 - loss: -0.3797 - dice_coef: 0.3797 - binary_accuracy: 0.57 - ETA: 59s - loss: -0.3798 - dice_coef: 0.3798 - binary_accuracy: 0.5737 - ETA: 58s - loss: -0.3798 - dice_coef: 0.3798 - binary_accuracy: 0.568 - ETA: 57s - loss: -0.3802 - dice_coef: 0.3802 - binary_accuracy: 0.564 - ETA: 57s - loss: -0.3793 - dice_coef: 0.3793 - binary_accuracy: 0.558 - ETA: 56s - loss: -0.3792 - dice_coef: 0.3792 - binary_accuracy: 0.55 ...
# 129/129 [==============================] - ETA: 10s - loss: -0.3830 - dice_coef: 0.3830 - binary_accuracy: 0.430 - ETA: 9s - loss: -0.3831 - dice_coef: 0.3831 - binary_accuracy: 0.429 - ETA: 8s - loss: -0.3830 - dice_coef: 0.3830 - binary_accuracy: 0.42 - ETA: 8s - loss: -0.3830 - dice_coef: 0.3830 - binary_accuracy: 0.42 - ETA: 7s - loss: -0.3828 - dice_coef: 0.3828 - binary_accuracy: 0.42 - ETA: 6s - loss: -0.3827 - dice_coef: 0.3827 - binary_accuracy: 0.42 - ETA: 5s - loss: -0.3827 - dice_coef: 0.3827 - binary_accuracy: 0.42 - ETA: 5s - loss: -0.3829 - dice_coef: 0.3829 - binary_accuracy: 0.42 - ETA: 4s - loss: -0.3831 - dice_coef: 0.3831 - binary_accuracy: 0.42 - ETA: 3s - loss: -0.3833 - dice_coef: 0.3833 - binary_accuracy: 0.42 - ETA: 2s - loss: -0.3834 - dice_coef: 0.3834 - binary_accuracy: 0.42 - ETA: 2s - loss: -0.3837 - dice_coef: 0.3837 - binary_accuracy: 0.42 - ETA: 1s - loss: -0.3838 - dice_coef: 0.3838 - binary_accuracy: 0.42 - ETA: 0s - loss: -0.3839 - dice_coef: 0.3839 - binary_accuracy: 0.41 - 97s 750ms/step - loss: -0.3843 - dice_coef: 0.3843 - binary_accuracy: 0.4189 - val_loss: -0.3843 - val_dice_coef: 0.3843 - val_binary_accuracy: 0.3040
#
# Epoch 00001: loss improved from inf to -0.38431, saving model to unet_lung_seg.hdf5
# Epoch 2/4
# 114/129 [=========================>....] - ETA: 1:30 - loss: -0.3973 - dice_coef: 0.3973 - binary_accuracy: 0.32 - ETA: 1:30 - loss: -0.3928 - dice_coef: 0.3928 - binary_accuracy: 0.31 - ETA: 1:29 - loss: -0.4050 - dice_coef: 0.4050 - binary_accuracy: 0.33 - ETA: 1:29 - loss: -0.4020 - dice_coef: 0.4020 - binary_accuracy: 0.32 - ETA: 1:28 - loss: -0.4083 - dice_coef: 0.4083 - binary_accuracy: 0.33 - ETA: 1:29 - loss: -0.4084 - dice_coef: 0.4084 - binary_accuracy: 0.33 - ETA: 1:29 - loss: -0.4040 - dice_coef: 0.4040 - binary_accuracy: 0.33 - ETA: 1:29 - loss: -0.3996 - dice_coef: 0.3996 - binary_accuracy: 0.32 - ETA: 1:28 - loss: -0.3968 - dice_coef: 0.3968 - binary_accuracy: 0.32 - ETA: 1:28 - loss: -0.3930 - dice_coef: 0.3930 - binary_accuracy: 0.31 - ETA: 1:27 - loss: -0.3913 - dice_coef: 0.3913 - binary_accuracy: 0.31 - ETA: 1:27 - loss: -0.3903 - dice_coef: 0.3903 - binary_accuracy: 0.31 - ETA: 1:26 - loss: -0.3904 - dice_coef: 0.3904 - binary_accuracy: 0.31 - ETA: 1:25 - loss: -0.3901 - dice_coef: 0.3901 - binary_accuracy: 0.31 - ETA: 1:24 - loss: -0.3883 - dice_coef: 0.3883 - binary_accuracy: 0.31 - ETA: 1:23 - loss: -0.3882 - dice_coef: 0.3882 - binary_accuracy: 0.31 - ETA: 1:23 - loss: -0.3911 - dice_coef: 0.3911 - binary_accuracy: 0.31 - ETA: 1:22 - loss: -0.3894 - dice_coef: 0.3894 - binary_accuracy: 0.31 - ETA: 1:21 - loss: -0.3877 - dice_coef: 0.3877 - binary_accuracy: 0.31 - ETA: 1:20 - loss: -0.3877 - dice_coef: 0.3877 - binary_accuracy: 0.31 - ETA: 1:19 - loss: -0.3839 - dice_coef: 0.3839 - binary_accuracy: 0.30 - ETA: 1:18 - loss: -0.3829 - dice_coef: 0.3829 - binary_accuracy: 0.30 - ETA: 1:18 - loss: -0.3839 - dice_coef: 0.3839 - binary_accuracy: 0.30 - ETA: 1:17 - loss: -0.3843 - dice_coef: 0.3843 - binary_accuracy: 0.30 - ETA: 1:16 - loss: -0.3842 - dice_coef: 0.3842 - binary_accuracy: 0.30 - ETA: 1:16 - loss: -0.3849 - dice_coef: 0.3849 - binary_accuracy: 0.30 - ETA: 1:15 - loss: -0.3868 - dice_coef: 0.3868 - binary_accuracy: 0.30 - ETA: 1:14 - loss: -0.3858 - dice_coef: 0.3858 - binary_accuracy: 0.30 - ETA: 1:14 - loss: -0.3865 - dice_coef: 0.3865 - binary_accuracy: 0.30 - ETA: 1:13 - loss: -0.3855 - dice_coef: 0.3855 - binary_accuracy: 0.30 - ETA: 1:12 - loss: -0.3863 - dice_coef: 0.3863 - binary_accuracy: 0.30 - ETA: 1:11 - loss: -0.3873 - dice_coef: 0.3873 - binary_accuracy: 0.30 - ETA: 1:11 - loss: -0.3866 - dice_coef: 0.3866 - binary_accuracy: 0.30 - ETA: 1:10 - loss: -0.3877 - dice_coef: 0.3877 - binary_accuracy: 0.30 - ETA: 1:09 - loss: -0.3883 - dice_coef: 0.3883 - binary_accuracy: 0.30 - ETA: 1:08 - loss: -0.3874 - dice_coef: 0.3874 - binary_accuracy: 0.30 - ETA: 1:08 - loss: -0.3872 - dice_coef: 0.3872 - binary_accuracy: 0.30 - ETA: 1:07 - loss: -0.3874 - dice_coef: 0.3874 - binary_accuracy: 0.30 - ETA: 1:06 - loss: -0.3875 - dice_coef: 0.3875 - binary_accuracy: 0.30 - ETA: 1:05 - loss: -0.3876 - dice_coef: 0.3876 - binary_accuracy: 0.30 - ETA: 1:05 - loss: -0.3887 - dice_coef: 0.3887 - binary_accuracy: 0.30 - ETA: 1:04 - loss: -0.3886 - dice_coef: 0.3886 - binary_accuracy: 0.30 - ETA: 1:03 - loss: -0.3879 - dice_coef: 0.3879 - binary_accuracy: 0.30 - ETA: 1:02 - loss: -0.3885 - dice_coef: 0.3885 - binary_accuracy: 0.30 - ETA: 1:02 - loss: -0.3894 - dice_coef: 0.3894 - binary_accuracy: 0.30 - ETA: 1:01 - loss: -0.3892 - dice_coef: 0.3892 - binary_accuracy: 0.30 - ETA: 1:00 - loss: -0.3898 - dice_coef: 0.3898 - binary_accuracy: 0.31 - ETA: 59s - loss: -0.3906 - dice_coef: 0.3906 - binary_accuracy: 0.3107 - ETA: 59s - loss: -0.3907 - dice_coef: 0.3907 - binary_accuracy: 0.310 - ETA: 58s - loss: -0.3914 - dice_coef: 0.3914 - binary_accuracy: 0.311 - ETA: 57s - loss: -0.3921 - dice_coef: 0.3921 - binary_accuracy: 0.311 - ETA: 56s - loss: -0.3921 - dice_coef: 0.3921 - binary_accuracy: 0.311 - ETA: 56s - loss: -0.3923 - dice_coef: 0.3923 - binary_accuracy: 0.311 - ETA: 55s - loss: -0.3929 - dice_coef: 0.3929 - binary_accuracy: 0.311 - ETA: 54s - loss: -0.3930 - dice_coef: 0.3930 - binary_accuracy: 0.31 ...
# 129/129 [==============================] - ETA: 10s - loss: -0.4330 - dice_coef: 0.4330 - binary_accuracy: 0.310 - ETA: 9s - loss: -0.4337 - dice_coef: 0.4337 - binary_accuracy: 0.310 - ETA: 8s - loss: -0.4345 - dice_coef: 0.4345 - binary_accuracy: 0.31 - ETA: 8s - loss: -0.4349 - dice_coef: 0.4349 - binary_accuracy: 0.31 - ETA: 7s - loss: -0.4350 - dice_coef: 0.4350 - binary_accuracy: 0.31 - ETA: 6s - loss: -0.4358 - dice_coef: 0.4358 - binary_accuracy: 0.31 - ETA: 5s - loss: -0.4360 - dice_coef: 0.4360 - binary_accuracy: 0.31 - ETA: 5s - loss: -0.4363 - dice_coef: 0.4363 - binary_accuracy: 0.31 - ETA: 4s - loss: -0.4366 - dice_coef: 0.4366 - binary_accuracy: 0.31 - ETA: 3s - loss: -0.4375 - dice_coef: 0.4375 - binary_accuracy: 0.31 - ETA: 2s - loss: -0.4380 - dice_coef: 0.4380 - binary_accuracy: 0.31 - ETA: 2s - loss: -0.4385 - dice_coef: 0.4385 - binary_accuracy: 0.31 - ETA: 1s - loss: -0.4391 - dice_coef: 0.4391 - binary_accuracy: 0.31 - ETA: 0s - loss: -0.4397 - dice_coef: 0.4397 - binary_accuracy: 0.31 - 95s 736ms/step - loss: -0.4401 - dice_coef: 0.4401 - binary_accuracy: 0.3116 - val_loss: -0.4799 - val_dice_coef: 0.4799 - val_binary_accuracy: 0.3032
#
# Epoch 00002: loss improved from -0.38431 to -0.44013, saving model to unet_lung_seg.hdf5
# Epoch 3/4
# 114/129 [=========================>....] - ETA: 1:33 - loss: -0.4534 - dice_coef: 0.4534 - binary_accuracy: 0.27 - ETA: 1:34 - loss: -0.4821 - dice_coef: 0.4821 - binary_accuracy: 0.30 - ETA: 1:34 - loss: -0.5079 - dice_coef: 0.5079 - binary_accuracy: 0.32 - ETA: 1:34 - loss: -0.5182 - dice_coef: 0.5182 - binary_accuracy: 0.33 - ETA: 1:33 - loss: -0.5086 - dice_coef: 0.5086 - binary_accuracy: 0.32 - ETA: 1:32 - loss: -0.5070 - dice_coef: 0.5070 - binary_accuracy: 0.32 - ETA: 1:32 - loss: -0.5018 - dice_coef: 0.5018 - binary_accuracy: 0.32 - ETA: 1:31 - loss: -0.5068 - dice_coef: 0.5068 - binary_accuracy: 0.32 - ETA: 1:30 - loss: -0.4973 - dice_coef: 0.4973 - binary_accuracy: 0.31 - ETA: 1:29 - loss: -0.4948 - dice_coef: 0.4948 - binary_accuracy: 0.31 - ETA: 1:28 - loss: -0.4963 - dice_coef: 0.4963 - binary_accuracy: 0.31 - ETA: 1:28 - loss: -0.4975 - dice_coef: 0.4975 - binary_accuracy: 0.31 - ETA: 1:27 - loss: -0.4969 - dice_coef: 0.4969 - binary_accuracy: 0.31 - ETA: 1:26 - loss: -0.4956 - dice_coef: 0.4956 - binary_accuracy: 0.31 - ETA: 1:25 - loss: -0.4939 - dice_coef: 0.4939 - binary_accuracy: 0.31 - ETA: 1:24 - loss: -0.4981 - dice_coef: 0.4981 - binary_accuracy: 0.31 - ETA: 1:23 - loss: -0.4993 - dice_coef: 0.4993 - binary_accuracy: 0.31 - ETA: 1:23 - loss: -0.5036 - dice_coef: 0.5036 - binary_accuracy: 0.32 - ETA: 1:22 - loss: -0.5031 - dice_coef: 0.5031 - binary_accuracy: 0.32 - ETA: 1:21 - loss: -0.5029 - dice_coef: 0.5029 - binary_accuracy: 0.32 - ETA: 1:20 - loss: -0.5044 - dice_coef: 0.5044 - binary_accuracy: 0.32 - ETA: 1:19 - loss: -0.5032 - dice_coef: 0.5032 - binary_accuracy: 0.32 - ETA: 1:19 - loss: -0.5023 - dice_coef: 0.5023 - binary_accuracy: 0.32 - ETA: 1:18 - loss: -0.5027 - dice_coef: 0.5027 - binary_accuracy: 0.32 - ETA: 1:17 - loss: -0.5018 - dice_coef: 0.5018 - binary_accuracy: 0.31 - ETA: 1:16 - loss: -0.5034 - dice_coef: 0.5034 - binary_accuracy: 0.31 - ETA: 1:16 - loss: -0.5030 - dice_coef: 0.5030 - binary_accuracy: 0.31 - ETA: 1:15 - loss: -0.5040 - dice_coef: 0.5040 - binary_accuracy: 0.31 - ETA: 1:14 - loss: -0.5050 - dice_coef: 0.5050 - binary_accuracy: 0.32 - ETA: 1:13 - loss: -0.5050 - dice_coef: 0.5050 - binary_accuracy: 0.31 - ETA: 1:13 - loss: -0.5051 - dice_coef: 0.5051 - binary_accuracy: 0.31 - ETA: 1:12 - loss: -0.5070 - dice_coef: 0.5070 - binary_accuracy: 0.32 - ETA: 1:11 - loss: -0.5069 - dice_coef: 0.5069 - binary_accuracy: 0.32 - ETA: 1:10 - loss: -0.5074 - dice_coef: 0.5074 - binary_accuracy: 0.32 - ETA: 1:10 - loss: -0.5070 - dice_coef: 0.5070 - binary_accuracy: 0.32 - ETA: 1:09 - loss: -0.5076 - dice_coef: 0.5076 - binary_accuracy: 0.32 - ETA: 1:08 - loss: -0.5081 - dice_coef: 0.5081 - binary_accuracy: 0.32 - ETA: 1:08 - loss: -0.5101 - dice_coef: 0.5101 - binary_accuracy: 0.32 - ETA: 1:07 - loss: -0.5087 - dice_coef: 0.5087 - binary_accuracy: 0.32 - ETA: 1:06 - loss: -0.5088 - dice_coef: 0.5088 - binary_accuracy: 0.32 - ETA: 1:05 - loss: -0.5066 - dice_coef: 0.5066 - binary_accuracy: 0.31 - ETA: 1:05 - loss: -0.5065 - dice_coef: 0.5065 - binary_accuracy: 0.31 - ETA: 1:04 - loss: -0.5068 - dice_coef: 0.5068 - binary_accuracy: 0.31 - ETA: 1:03 - loss: -0.5067 - dice_coef: 0.5067 - binary_accuracy: 0.31 - ETA: 1:03 - loss: -0.5068 - dice_coef: 0.5068 - binary_accuracy: 0.31 - ETA: 1:02 - loss: -0.5068 - dice_coef: 0.5068 - binary_accuracy: 0.31 - ETA: 1:01 - loss: -0.5077 - dice_coef: 0.5077 - binary_accuracy: 0.31 - ETA: 1:00 - loss: -0.5061 - dice_coef: 0.5061 - binary_accuracy: 0.31 - ETA: 1:00 - loss: -0.5065 - dice_coef: 0.5065 - binary_accuracy: 0.31 - ETA: 59s - loss: -0.5075 - dice_coef: 0.5075 - binary_accuracy: 0.3203 - ETA: 58s - loss: -0.5080 - dice_coef: 0.5080 - binary_accuracy: 0.321 - ETA: 57s - loss: -0.5087 - dice_coef: 0.5087 - binary_accuracy: 0.322 - ETA: 57s - loss: -0.5087 - dice_coef: 0.5087 - binary_accuracy: 0.324 - ETA: 56s - loss: -0.5091 - dice_coef: 0.5091 - binary_accuracy: 0.326 - ETA: 55s - loss: -0.5088 - dice_coef: 0.5088 - binary_accuracy: 0.32 ...
# 129/129 [==============================] - ETA: 10s - loss: -0.5354 - dice_coef: 0.5354 - binary_accuracy: 0.463 - ETA: 10s - loss: -0.5363 - dice_coef: 0.5363 - binary_accuracy: 0.465 - ETA: 9s - loss: -0.5368 - dice_coef: 0.5368 - binary_accuracy: 0.467 - ETA: 8s - loss: -0.5379 - dice_coef: 0.5379 - binary_accuracy: 0.46 - ETA: 7s - loss: -0.5385 - dice_coef: 0.5385 - binary_accuracy: 0.47 - ETA: 7s - loss: -0.5391 - dice_coef: 0.5391 - binary_accuracy: 0.47 - ETA: 6s - loss: -0.5393 - dice_coef: 0.5393 - binary_accuracy: 0.47 - ETA: 5s - loss: -0.5403 - dice_coef: 0.5403 - binary_accuracy: 0.47 - ETA: 4s - loss: -0.5411 - dice_coef: 0.5411 - binary_accuracy: 0.47 - ETA: 3s - loss: -0.5415 - dice_coef: 0.5415 - binary_accuracy: 0.47 - ETA: 3s - loss: -0.5426 - dice_coef: 0.5426 - binary_accuracy: 0.47 - ETA: 2s - loss: -0.5435 - dice_coef: 0.5435 - binary_accuracy: 0.47 - ETA: 1s - loss: -0.5444 - dice_coef: 0.5444 - binary_accuracy: 0.48 - ETA: 0s - loss: -0.5451 - dice_coef: 0.5451 - binary_accuracy: 0.48 - 102s 788ms/step - loss: -0.5457 - dice_coef: 0.5457 - binary_accuracy: 0.4843 - val_loss: -0.6498 - val_dice_coef: 0.6498 - val_binary_accuracy: 0.6803
#
# Epoch 00003: loss improved from -0.44013 to -0.54569, saving model to unet_lung_seg.hdf5
# Epoch 4/4
# 114/129 [=========================>....] - ETA: 1:45 - loss: -0.5669 - dice_coef: 0.5669 - binary_accuracy: 0.66 - ETA: 1:46 - loss: -0.6184 - dice_coef: 0.6184 - binary_accuracy: 0.70 - ETA: 1:45 - loss: -0.6142 - dice_coef: 0.6142 - binary_accuracy: 0.73 - ETA: 1:44 - loss: -0.4677 - dice_coef: 0.4677 - binary_accuracy: 0.72 - ETA: 1:43 - loss: -0.3744 - dice_coef: 0.3744 - binary_accuracy: 0.72 - ETA: 1:42 - loss: -0.3120 - dice_coef: 0.3120 - binary_accuracy: 0.71 - ETA: 1:41 - loss: -0.2675 - dice_coef: 0.2675 - binary_accuracy: 0.71 - ETA: 1:40 - loss: -0.2340 - dice_coef: 0.2340 - binary_accuracy: 0.71 - ETA: 1:39 - loss: -0.2080 - dice_coef: 0.2080 - binary_accuracy: 0.71 - ETA: 1:38 - loss: -0.1872 - dice_coef: 0.1872 - binary_accuracy: 0.71 - ETA: 1:37 - loss: -0.1702 - dice_coef: 0.1702 - binary_accuracy: 0.71 - ETA: 1:37 - loss: -0.1560 - dice_coef: 0.1560 - binary_accuracy: 0.71 - ETA: 1:36 - loss: -0.1440 - dice_coef: 0.1440 - binary_accuracy: 0.71 - ETA: 1:36 - loss: -0.1337 - dice_coef: 0.1337 - binary_accuracy: 0.71 - ETA: 1:35 - loss: -0.1248 - dice_coef: 0.1248 - binary_accuracy: 0.71 - ETA: 1:34 - loss: -0.1170 - dice_coef: 0.1170 - binary_accuracy: 0.71 - ETA: 1:33 - loss: -0.1101 - dice_coef: 0.1101 - binary_accuracy: 0.70 - ETA: 1:32 - loss: -0.1040 - dice_coef: 0.1040 - binary_accuracy: 0.70 - ETA: 1:31 - loss: -0.0985 - dice_coef: 0.0985 - binary_accuracy: 0.70 - ETA: 1:31 - loss: -0.0936 - dice_coef: 0.0936 - binary_accuracy: 0.70 - ETA: 1:30 - loss: -0.0892 - dice_coef: 0.0892 - binary_accuracy: 0.70 - ETA: 1:29 - loss: -0.0851 - dice_coef: 0.0851 - binary_accuracy: 0.70 - ETA: 1:28 - loss: -0.0814 - dice_coef: 0.0814 - binary_accuracy: 0.69 - ETA: 1:27 - loss: -0.0780 - dice_coef: 0.0780 - binary_accuracy: 0.69 - ETA: 1:26 - loss: -0.0749 - dice_coef: 0.0749 - binary_accuracy: 0.69 - ETA: 1:25 - loss: -0.0720 - dice_coef: 0.0720 - binary_accuracy: 0.69 - ETA: 1:24 - loss: -0.0693 - dice_coef: 0.0693 - binary_accuracy: 0.69 - ETA: 1:24 - loss: -0.0669 - dice_coef: 0.0669 - binary_accuracy: 0.69 - ETA: 1:23 - loss: -0.0646 - dice_coef: 0.0646 - binary_accuracy: 0.69 - ETA: 1:22 - loss: -0.0624 - dice_coef: 0.0624 - binary_accuracy: 0.69 - ETA: 1:21 - loss: -0.0604 - dice_coef: 0.0604 - binary_accuracy: 0.69 - ETA: 1:20 - loss: -0.0585 - dice_coef: 0.0585 - binary_accuracy: 0.69 - ETA: 1:19 - loss: -0.0567 - dice_coef: 0.0567 - binary_accuracy: 0.69 - ETA: 1:19 - loss: -0.0551 - dice_coef: 0.0551 - binary_accuracy: 0.69 - ETA: 1:18 - loss: -0.0535 - dice_coef: 0.0535 - binary_accuracy: 0.69 - ETA: 1:17 - loss: -0.0520 - dice_coef: 0.0520 - binary_accuracy: 0.69 - ETA: 1:16 - loss: -0.0506 - dice_coef: 0.0506 - binary_accuracy: 0.69 - ETA: 1:15 - loss: -0.0493 - dice_coef: 0.0493 - binary_accuracy: 0.69 - ETA: 1:15 - loss: -0.0480 - dice_coef: 0.0480 - binary_accuracy: 0.69 - ETA: 1:14 - loss: -0.0468 - dice_coef: 0.0468 - binary_accuracy: 0.69 - ETA: 1:13 - loss: -0.0457 - dice_coef: 0.0457 - binary_accuracy: 0.69 - ETA: 1:12 - loss: -0.0446 - dice_coef: 0.0446 - binary_accuracy: 0.69 - ETA: 1:11 - loss: -0.0435 - dice_coef: 0.0435 - binary_accuracy: 0.69 - ETA: 1:10 - loss: -0.0426 - dice_coef: 0.0426 - binary_accuracy: 0.69 - ETA: 1:09 - loss: -0.0416 - dice_coef: 0.0416 - binary_accuracy: 0.69 - ETA: 1:09 - loss: -0.0407 - dice_coef: 0.0407 - binary_accuracy: 0.69 - ETA: 1:08 - loss: -0.0398 - dice_coef: 0.0398 - binary_accuracy: 0.69 - ETA: 1:07 - loss: -0.0390 - dice_coef: 0.0390 - binary_accuracy: 0.69 - ETA: 1:06 - loss: -0.0382 - dice_coef: 0.0382 - binary_accuracy: 0.69 - ETA: 1:05 - loss: -0.0374 - dice_coef: 0.0374 - binary_accuracy: 0.69 - ETA: 1:04 - loss: -0.0367 - dice_coef: 0.0367 - binary_accuracy: 0.69 - ETA: 1:04 - loss: -0.0360 - dice_coef: 0.0360 - binary_accuracy: 0.69 - ETA: 1:03 - loss: -0.0353 - dice_coef: 0.0353 - binary_accuracy: 0.69 - ETA: 1:02 - loss: -0.0347 - dice_coef: 0.0347 - binary_accuracy: 0.69 - ETA: 1:01 - loss: -0.0340 - dice_coef: 0.0340 - binary_accuracy: 0.69 ...
# 129/129 [==============================] - ETA: 11s - loss: -0.0163 - dice_coef: 0.0163 - binary_accuracy: 0.689 - ETA: 10s - loss: -0.0161 - dice_coef: 0.0161 - binary_accuracy: 0.689 - ETA: 9s - loss: -0.0160 - dice_coef: 0.0160 - binary_accuracy: 0.689 - ETA: 9s - loss: -0.0159 - dice_coef: 0.0159 - binary_accuracy: 0.68 - ETA: 8s - loss: -0.0157 - dice_coef: 0.0157 - binary_accuracy: 0.68 - ETA: 7s - loss: -0.0156 - dice_coef: 0.0156 - binary_accuracy: 0.68 - ETA: 6s - loss: -0.0155 - dice_coef: 0.0155 - binary_accuracy: 0.68 - ETA: 5s - loss: -0.0154 - dice_coef: 0.0154 - binary_accuracy: 0.68 - ETA: 4s - loss: -0.0152 - dice_coef: 0.0152 - binary_accuracy: 0.68 - ETA: 4s - loss: -0.0151 - dice_coef: 0.0151 - binary_accuracy: 0.68 - ETA: 3s - loss: -0.0150 - dice_coef: 0.0150 - binary_accuracy: 0.68 - ETA: 2s - loss: -0.0149 - dice_coef: 0.0149 - binary_accuracy: 0.68 - ETA: 1s - loss: -0.0147 - dice_coef: 0.0147 - binary_accuracy: 0.68 - ETA: 0s - loss: -0.0146 - dice_coef: 0.0146 - binary_accuracy: 0.68 - 108s 833ms/step - loss: -0.0145 - dice_coef: 0.0145 - binary_accuracy: 0.6892 - val_loss: -1.2503e-05 - val_dice_coef: 1.2503e-05 - val_binary_accuracy: 0.6957
#
# Epoch 00004: loss did not improve from -0.54569

# %% [markdown]
# # Results from training

# %%
fig, axs = plt.subplots(1, 2, figsize = (15, 4))

training_loss = history.history['loss']
validation_loss = history.history['val_loss']

training_accuracy = history.history['binary_accuracy']
validation_accuracy = history.history['val_binary_accuracy']

epoch_count = range(1, len(training_loss) + 1)

axs[0].plot(epoch_count, training_loss, 'r--')
axs[0].plot(epoch_count, validation_loss, 'b-')
axs[0].legend(['Training Loss', 'Validation Loss'])

axs[1].plot(epoch_count, training_accuracy, 'r--')
axs[1].plot(epoch_count, validation_accuracy, 'b-')
axs[1].legend(['Training Accuracy', 'Validation Accuracy'])

# %% [markdown]
# # Make Predictions

# %%
SEGMENTATION_PRED_DIR = os.path.join(SEGMENTATION_TEST_DIR,"predicted_masks")
test_gen = test_generator(test_files, target_size=(512,512))
results = model.predict_generator(test_gen, len(test_files), verbose=1)
save_result(SEGMENTATION_PRED_DIR, results, test_files)
# Out:
# 50/50 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 3s 68ms/step

# %%
image.size()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-bbdb6521895d> in <module>
# ----> 1 image.size()
#
# AttributeError: 'NoneType' object has no attribute 'size'

# %%
#C:\Users\vgsha\Desktop\Tutorial\input\ChinaSet_AllFiles\segmentation\test\image
image = cv2.imread("input/ChinaSet_AllFiles/segmentation/test/image/CHNCXR_0003_0.png")
predict_image = cv2.imread("input/ChinaSet_AllFiles/segmentation/test/predicted_masks/CHNCXR_0003_0_predict.png")
mask_image = cv2.imread("input/ChinaSet_AllFiles/segmentation/test/dilate/CHNCXR_0003_0.png")

fig, axs = plt.subplots(4, 3, figsize=(16, 16))

axs[0, 0].set_title("Predicted")
axs[0, 0].imshow(add_colored_mask(image, predict_image))
axs[0, 1].set_title("Gold Std.")
axs[0, 1].imshow(add_colored_mask(image, mask_image))
axs[0, 2].set_title("Diff.")
axs[0, 2].imshow(diff_mask(mask_image, predict_image))

image = cv2.imread("input/ChinaSet_AllFiles/segmentation/test/image/CHNCXR_0015_0.png")
predict_image = cv2.imread("input/ChinaSet_AllFiles/segmentation/test/predicted_masks/CHNCXR_0015_0_predict.png")
mask_image = cv2.imread("input/ChinaSet_AllFiles/segmentation/test/dilate/CHNCXR_0015_0.png")

axs[1, 0].set_title("Predicted")
axs[1, 0].imshow(add_colored_mask(image, predict_image))
axs[1, 1].set_title("Gold Std.")
axs[1, 1].imshow(add_colored_mask(image, mask_image))
axs[1, 2].set_title("Diff.")
axs[1, 2].imshow(diff_mask(mask_image, predict_image))

image = cv2.imread("input/ChinaSet_AllFiles/segmentation/test/image/CHNCXR_0028_0.png")
predict_image = cv2.imread("input/ChinaSet_AllFiles/segmentation/test/predicted_masks/CHNCXR_0028_0_predict.png")
mask_image = cv2.imread("input/ChinaSet_AllFiles/segmentation/test/dilate/CHNCXR_0028_0.png")

axs[2, 0].set_title("Predicted")
axs[2, 0].imshow(add_colored_mask(image, predict_image))
axs[2, 1].set_title("Gold Std.")
axs[2, 1].imshow(add_colored_mask(image, mask_image))
axs[2, 2].set_title("Diff.")
axs[2, 2].imshow(diff_mask(mask_image, predict_image))

image = cv2.imread("input/ChinaSet_AllFiles/segmentation/test/image/CHNCXR_0045_0.png")
predict_image = cv2.imread("input/ChinaSet_AllFiles/segmentation/test/predicted_masks/CHNCXR_0045_0_predict.png")
mask_image = cv2.imread("input/ChinaSet_AllFiles/segmentation/test/dilate/CHNCXR_0045_0.png")

axs[3, 0].set_title("Predicted")
axs[3, 0].imshow(add_colored_mask(image, predict_image))
axs[3, 1].set_title("Gold Std.")
axs[3, 1].imshow(add_colored_mask(image, mask_image))
axs[3, 2].set_title("Diff.")
axs[3, 2].imshow(diff_mask(mask_image, predict_image))
